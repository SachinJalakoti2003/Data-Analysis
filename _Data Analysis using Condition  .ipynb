# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv("googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
impute=SimpleImputer(missing_values=np.nan,strategy="mean")
impute.fit(df.iloc[:,2:3].values)
df.iloc[:,2:3]=impute.transform(df.iloc[:,2:3].values)

# %%
df.dropna()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # Q1.How many are there free apps in ART_AND_DESIGN

# %%
df["Category"]=="ART_AND_DESIGN"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Category, Length: 10841, dtype: bool

# %%
df_pr=df[df["Category"]=="ART_AND_DESIGN"]
len(df_pr[df_pr["Type"]=="Free"])
# Out:
# 62

# %% [markdown]
# # Q2.How many apps are there in ART_AND_DESIGN with rating 4.5

# %%
df_pr=df[df["Category"]=="ART_AND_DESIGN"]
print(len(df_pr[df_pr["Rating"]>4.5]))
# Out:
# 22

# %%
df_pr=df[df["Rating"]>4.5]
len(df_pr[df_pr["Category"]=="ART_AND_DESIGN"])
# Out:
# 22

# %% [markdown]
# # Q3.How many apps are there in the family  with rating mpre than 4.5 and free

# %%
df_pr=df[df["Category"]=="FAMILY"]
df_pr=df_pr[df_pr["Rating"]>4.5]
df_pr[df_pr["Type"]=="Free"]
# Out:
#                                                      App Category  Rating  \
# 2020   Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 2023                                     Candy Pop Story   FAMILY     4.7
# 2029                         Dog Run - Pet Dog Simulator   FAMILY     4.7
# 2032     Puzzle Kids - Animals Shapes and Jigsaw Puzzles   FAMILY     4.6
# 2040        No. Color - Color by Number, Number Coloring   FAMILY     4.8
# ...                                                  ...      ...     ...
# 10691                                             Pin-fo   FAMILY     4.6
# 10801                                Fr Ignacio Outreach   FAMILY     4.9
# 10809              Castle Clash: RPG War and Strategy FR   FAMILY     4.7
# 10820                                    Fr. Daoud Lamei   FAMILY     5.0
# 10837                   Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#       Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# # Q3.List all the apps with rating more than 4.5 and category is Family

# %%
df_pr=df[df["Category"]=="FAMILY"]
df_pr=df_pr[df_pr["Rating"]>4.5]
result=df_pr[df_pr["Type"]=="Free"].values

# %%
result
# Out:
# array([['Super ABC! Learning games for kids! Preschool apps', 'FAMILY',
#         4.6, ..., 'July 16, 2018', '1.1.6.7', '4.1 and up'],
#        ['Candy Pop Story', 'FAMILY', 4.7, ..., 'May 24, 2018',
#         '2.0.3165', '2.3 and up'],
#        ['Dog Run - Pet Dog Simulator', 'FAMILY', 4.7, ...,
#         'May 22, 2018', '1.4.12', '4.1 and up'],
#        ...,
#        ['Castle Clash: RPG War and Strategy FR', 'FAMILY', 4.7, ...,
#         'July 18, 2018', '1.4.2', '4.1 and up'],
#        ['Fr. Daoud Lamei', 'FAMILY', 5.0, ..., 'June 27, 2018', '3.8.0',
#         '4.1 and up'],
#        ['Fr. Mike Schmitz Audio Teachings', 'FAMILY', 5.0, ...,
#         'July 6, 2018', '1.0', '4.1 and up']], dtype=object)

# %%
for i in result:
    print(i[0])
# Out:
# Super ABC! Learning games for kids! Preschool apps
# Candy Pop Story
# Dog Run - Pet Dog Simulator
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# No. Color - Color by Number, Number Coloring
# Garden Fruit Legend
# Piano Kids - Music & Songs
# Duolingo: Learn Languages Free
# Super ABC! Learning games for kids! Preschool apps
# Drawing for Kids Learning Games for Toddlers age 3
# Baby ABC in box! Kids alphabet games for toddlers!
# Henry Danger Crime Warp
# Fruit Cube Blast
# Toddler Kids Puzzles PUZZINGO
# Fuzzy Seasons: Animal Forest
# Dog Run - Pet Dog Simulator
# My Oasis - Calming and Relaxing Idle Clicker Game
# Ninja Dash - Ronin Jump RPG
# Monster High™ Minis Mania
# Monica Toy TV
# Sworkit Kids - Fitness Meets Fun
# Crazy Colors: Bubbles Matching
# Pino chess
# Duolingo: Learn Languages Free
# Animal Jam - Play Wild!
# Dog Sim Online: Raise a Family
# Color by Number - Draw Sandbox Pixel Art
# Build a Bridge!
# Find a Way: Addictive Puzzle
# CompTIA Exam Training
# ...
